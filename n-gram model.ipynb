# %% [markdown]
# ### Import Necessary Dependencies

# %%
import pandas as pd
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
import requests
from collections import defaultdict
import random

# %% [markdown]
# ### Set Global Vars

# %%
root_url = "https://en.wikipedia.org"
iterations = 1
# With 2 I had the first set of links link to 100,717 articles...
links_set = set()
starting_page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
soup = BeautifulSoup(starting_page.content, 'html.parser')
initial_links = set([a['href'] for a in soup.find_all('a', href=True) if a['href'].startswith("/wiki") and all(["Wikipedia" not in a['href'], "Special" not in a['href'], "Template" not in a['href'], "File" not in a['href'], "Talk" not in a['href'], "Help" not in a['href'], "Portal" not in a['href'], "Main_Page" not in a['href'], "Category" not in a['href']])])
all_texts = []
all_grams = []
n = 3

# %%
def extract_text(iteration, new_links):
    new_links_copy = new_links.copy()
    if iteration == 0:
        return
    if iteration == iterations:
        for link in initial_links:   
            # might have to for loop with new_links here
            get_links(link, new_links)
        extract_text(iteration - 1, new_links)
    else:
        for link in new_links_copy:
            get_links(link, set())
        extract_text(iteration - 1, new_links)

# %%
def get_links(link, new_links):
    print(f"extracting {link}")
    page = requests.get(f"{root_url}{link}")
    soup = BeautifulSoup(page.content, 'html.parser')
    for p in soup.find_all('p'):
        text = p.get_text(strip=True)
        if text and text != '\n' and len(text.split()) > 5:
            if text.startswith("This is an accepted version"):
                continue
            all_texts.append(text)
    links_set.add(link)
    count = 0
    first_p = soup.find('p')
    if first_p:
        for a in first_p.find_all('a', href=True):
            new_link = a['href']
            if new_link.startswith("/wiki") and all(x not in new_link for x in ["Wikipedia", "Special", "Template", "File", "Talk", "Help", "Portal", "Main_Page", "Category"]):
                if new_link not in links_set:
                    new_links.add(new_link)
                    count += 1
    print(f"Added {count} links")

# %%
extract_text(iterations, set())
# Out:
# 2
# extracting /wiki/Gustav_Holst
# Added 403 links
# extracting /wiki/JJ_(singer)
# Added 379 links
# extracting /wiki/Holy_Roman_Emperor
# Added 635 links
# extracting /wiki/Treaty_of_Campo_Formio
# Added 576 links
# extracting /wiki/Ng_Sui
# Added 69 links
# extracting /wiki/George_Floyd
# Added 847 links
# extracting /wiki/Dunkirk_evacuation
# Added 505 links
# extracting /wiki/George_Band
# Added 103 links
# extracting /wiki/M23_campaign_(2022%E2%80%93present)
# Added 1493 links
# extracting /wiki/Griffith_Park_Zoo
# Added 214 links
# extracting /wiki/Cillian_Murphy
# Added 856 links
# extracting /wiki/Belgian_Resistance
# Added 259 links
# extracting /wiki/Kangchenjunga
# Added 812 links
# extracting /wiki/President_of_Romania
# Added 682 links
# extracting /wiki/Heart_Lamp:_Selected_Stories
# Added 29 links
# extracting /wiki/Frank_Schofield
# Added 86 links
# extracting /wiki/Banu_Mushtaq
# Added 36 links
# extracting /wiki/Army_of_Italy_(France)
# Added 67 links
# extracting /wiki/Anna_Maria_R%C3%BCckersch%C3%B6ld
# Added 25 links
# extracting /wiki/Russian_invasion_of_Ukraine
# Added 2758 links
# extracting /wiki/1810
# Added 525 links
# extracting /wiki/Independence_Day_(Jordan)
# Added 24 links
# extracting /wiki/Jean-Baptiste_Jourdan
# Added 879 links
# extracting /wiki/Stoughton_station
# Added 167 links
# extracting /wiki/Joe_Brown_(climber)
# Added 264 links
# extracting /wiki/Dracunculiasis
# Added 416 links
# extracting /wiki/Austrian_Empire
# Added 832 links
# extracting /wiki/Open_cabildo
# Added 62 links
# extracting /wiki/Black_Lives_Matter_art
# Added 419 links
# extracting /wiki/Bachtiar_Basri
# Added 30 links
# extracting /wiki/Benjamin_Ritchie
# Added 75 links
# extracting /wiki/Chinese_characters
# Added 1545 links
# extracting /wiki/2025_Romanian_presidential_election
# Added 1317 links
# extracting /wiki/Army_of_the_Rhine_and_Moselle
# Added 353 links
# extracting /wiki/French_Revolutionary_Wars
# Added 1245 links
# extracting /wiki/Greenpoint,_Brooklyn
# Added 459 links
# extracting /wiki/Encyclopedia
# Added 316 links
# extracting /wiki/CSS
# Added 584 links
# extracting /wiki/Timeline_of_the_Russian_invasion_of_Ukraine_(1_January_2025_%E2%80%93_present)
# Added 1697 links
# extracting /wiki/User:Rhododendrites
# Added 533 links
# extracting /wiki/Kapsan_faction_incident
# Added 297 links
# extracting /wiki/Army_of_Sambre_and_Meuse
# Added 376 links
# extracting /wiki/CSS_fingerprinting
# Added 35 links
# extracting /wiki/Deepa_Bhasthi
# Added 13 links
# extracting /wiki/Battle_of_W%C3%BCrzburg
# Added 595 links
# extracting /wiki/2025_Portuguese_legislative_election
# Added 638 links
# extracting /wiki/May_25
# Added 1258 links
# extracting /wiki/Jordan
# Added 1423 links
# extracting /wiki/1940
# Added 2622 links
# extracting /wiki/Supreme_Leader_(North_Korean_title)
# Added 560 links
# extracting /wiki/Ivan_the_Terrible_(polar_bear)
# Added 24 links
# extracting /wiki/War_of_the_First_Coalition
# Added 816 links
# extracting /wiki/2020
# Added 2107 links
# extracting /wiki/Buenos_Aires
# Added 2104 links
# extracting /wiki/Sudanese_civil_war_(2023%E2%80%93present)
# Added 1376 links
# extracting /wiki/Archduke_Charles,_Duke_of_Teschen
# Added 1224 links
# extracting /wiki/1955
# Added 2703 links
# extracting /wiki/Black_Lives_Matter
# Added 1435 links
# extracting /wiki/Rhine_campaign_of_1796
# Added 473 links
# extracting /wiki/Boulogne-sur-Mer
# Added 1210 links
# extracting /wiki/1967
# Added 2560 links
# extracting /wiki/Kim_Jong-il
# Added 849 links
# extracting /wiki/List_of_days_of_the_year
# Added 371 links
# extracting /wiki/Midwestern_United_States
# Added 2229 links
# extracting /wiki/Eddie_Sheldrake
# Added 116 links
# extracting /wiki/Napoleon
# Added 2169 links
# extracting /wiki/Nicu%C8%99or_Dan
# Added 289 links
# extracting /wiki/Jadwiga_Rapp%C3%A9
# Added 124 links
# extracting /wiki/Sebonack_Golf_Club
# Added 27 links
# extracting /wiki/Kajaani_Castle
# Added 143 links
# extracting /wiki/Africa_Day
# Added 395 links
# extracting /wiki/Cranberry_scare_of_1959
# Added 35 links
# extracting /wiki/Daniel_Bilalian
# Added 30 links
# extracting /wiki/Austria_in_the_Eurovision_Song_Contest
# Added 1009 links
# extracting /wiki/Presidential_Medal_of_Freedom
# Added 284 links
# extracting /wiki/Derek_Chauvin
# Added 416 links
# extracting /wiki/Kim_Il-sung
# Added 1477 links
# extracting /wiki/Ezra_Pound
# Added 2341 links
# extracting /wiki/Minneapolis
# Added 2195 links
# extracting /wiki/Mary_Magdalene_de%27_Pazzi
# Added 82 links
# extracting /wiki/Wikimedia_Foundation
# Added 485 links
# extracting /wiki/Free_content
# Added 318 links
# extracting /wiki/Primera_Junta
# Added 375 links
# extracting /wiki/1963
# Added 2337 links
# extracting /wiki/May_26
# Added 1209 links
# extracting /wiki/Vienna
# Added 1708 links
# extracting /wiki/International_Booker_Prize
# Added 724 links
# extracting /wiki/Andr%C3%A9e_Dumon
# Added 38 links
# extracting /wiki/Battle_of_Boulogne
# Added 806 links
# extracting /wiki/Battle_of_Amberg
# Added 572 links
# extracting /wiki/Eurovision_Song_Contest_2025
# Added 1739 links
# extracting /wiki/WLNY-TV
# Added 934 links
# extracting /wiki/Assembly_of_the_Republic_(Portugal)
# Added 777 links
# extracting /wiki/Werenoi
# Added 29 links
# extracting /wiki/World_War_II
# Added 2926 links
# extracting /wiki/Wasted_Love_(JJ_song)
# Added 590 links
# extracting /wiki/May_24
# Added 1196 links
# extracting /wiki/George_Floyd_protests
# Added 2661 links
# extracting /wiki/Timeline_of_the_Sudanese_civil_war_(2025)
# Added 285 links
# extracting /wiki/Murder_of_George_Floyd
# Added 1180 links
# extracting /wiki/French_First_Republic
# Added 796 links
# extracting /wiki/Deaths_in_2025
# Added 1215 links
# extracting /wiki/Democratic_Alliance_(Portugal,_2024)
# Added 95 links
# extracting /wiki/May_Revolution
# Added 489 links
# extracting /wiki/1946
# Added 3529 links
# extracting /wiki/Dunkirk
# Added 967 links
# extracting /wiki/List_of_unarmed_African_Americans_killed_by_law_enforcement_officers_in_the_United_States
# Added 1425 links
# extracting /wiki/CBS
# Added 1711 links
# extracting /wiki/1955_British_Kangchenjunga_expedition
# Added 134 links
# extracting /wiki/Southeastern_United_States
# Added 831 links
# extracting /wiki/Gaza_war
# Added 3243 links
# extracting /wiki/Street_art
# Added 1302 links
# extracting /wiki/Tornado_outbreak_sequence_of_May_15%E2%80%9316,_2025
# Added 526 links
# extracting /wiki/Jean_Victor_Marie_Moreau
# Added 554 links
# extracting /wiki/English_language
# Added 2023 links
# 1
# extracting /wiki/Jules_Develle
# Added 442 links
# extracting /wiki/Chomo_Lonzo
# Added 204 links
# extracting /wiki/Widehem
# Added 918 links
# extracting /wiki/Vitoria,_Spain
# Added 635 links
# extracting /wiki/Greensboro-High_Point,_NC_Metropolitan_Statistical_Area
# Added 744 links
# extracting /wiki/D%C3%B4me_de_Rochefort
# Added 211 links
# extracting /wiki/Enrico_Colantoni
# Added 237 links
# extracting /wiki/Military_history_of_New_Zealand_during_World_War_II
# Added 1071 links
# extracting /wiki/Premier_of_the_People%27s_Republic_of_China
# Added 1136 links
# extracting /wiki/Charles_IX_of_France
# Added 314 links
# extracting /wiki/Richard_Epcar
# Added 272 links
# extracting /wiki/The_Dragon_Lord_(Morwood_novel)
# Added 9 links
# extracting /wiki/Leap_year_starting_on_Monday
# Added 236 links
# extracting /wiki/Siege_of_Mantua_(1796%E2%80%931797)
# Added 293 links
# extracting /wiki/Battle_of_Aqaba
# Added 244 links
# extracting /wiki/Greater_Caribbean
# Added 135 links
# extracting /wiki/Mozarthaus_Vienna
# Added 75 links
# extracting /wiki/Martina_Pippal
# Added 42 links
# extracting /wiki/2020s_in_United_States_history
# Added 1254 links
# extracting /wiki/Kaaris
# Added 94 links
# extracting /wiki/Peace_of_Basel
# Added 473 links
# extracting /wiki/Franklin_Steele
# Added 86 links
# extracting /wiki/Sweden_in_the_Eurovision_Song_Contest_1999
# Added 294 links
# extracting /wiki/CeNARD
# Added 196 links
# extracting /wiki/Louisiana_Hayride
# Added 148 links
# extracting /wiki/Pearl_Harbor
# Added 77 links
# extracting /wiki/Svika_Pick
# Added 447 links
# extracting /wiki/Pont-%C3%A0-Marcq
# Added 675 links
# extracting /wiki/North_Sea_Germanic
# Added 340 links
# extracting /wiki/Alex_Trebek
# Added 631 links
# extracting /wiki/Multiculturalism
# Added 2666 links
# extracting /wiki/Boston
# Added 2402 links
# extracting /wiki/Northcote,_Victoria
# Added 183 links
# extracting /wiki/Ghana_national_football_team
# Added 2348 links
# extracting /wiki/Wayne_Brown_(New_Zealand_politician)
# Added 221 links
# extracting /wiki/1755_Lisbon_earthquake
# Added 632 links
# extracting /wiki/First_Kishida_Cabinet
# Added 260 links
# extracting /wiki/El_Morabba3
# Added 90 links
# extracting /wiki/Keystroke_logging
# Added 336 links
# extracting /wiki/Plantation_house
# Added 128 links
# extracting /wiki/Thiant
# Added 673 links
# extracting /wiki/Jorge_Luis_Borges
# Added 707 links
# extracting /wiki/Royal_Opera_House
# Added 714 links
# extracting /wiki/Munich
# Added 2296 links
# extracting /wiki/Eurovision_Song_Contest_1965
# Added 765 links
# extracting /wiki/Faro_District
# Added 175 links
# extracting /wiki/Deepnet_Explorer
# Added 465 links
# extracting /wiki/Bismarck,_North_Dakota
# Added 888 links
# extracting /wiki/Blister
# Added 141 links
# extracting /wiki/Eug%C3%A8ne_Spuller
# Added 261 links
# extracting /wiki/Bruce_Foxton
# Added 202 links
# extracting /wiki/Jamal_Mitchell
# Added 189 links
# extracting /wiki/Jacques-Nicolas_Billaud-Varenne
# Added 578 links
# extracting /wiki/Ulas_Samchuk
# Added 83 links
# extracting /wiki/Villa_Tesei
# Added 165 links
# extracting /wiki/Further_Austria
# Added 275 links
# extracting /wiki/Surrender_of_Caserta
# Added 494 links
# extracting /wiki/Chambers_(publisher)
# Added 130 links
# extracting /wiki/Sheryl_Lee
# Added 299 links
# extracting /wiki/Al_Jazeera_English
# Added 630 links
# extracting /wiki/General_Secretary_and_Secretary_of_the_Workers%27_Party_of_Korea
# Added 193 links
# extracting /wiki/Yiwen_Leiju
# Added 14 links
# extracting /wiki/Ruth_Buzzi
# Added 396 links
# extracting /wiki/Robert_Redford
# Added 1885 links
# extracting /wiki/Douglas_fir
# Added 514 links
# extracting /wiki/Killings_and_massacres_during_the_1948_Palestine_war
# Added 607 links
# extracting /wiki/HM_Prison_Pentonville
# Added 174 links
# extracting /wiki/Thirteenth_Amendment_to_the_United_States_Constitution
# Added 1902 links
# extracting /wiki/Musical_theater
# Added 997 links
# extracting /wiki/Robert_Tilton
# Added 126 links
# extracting /wiki/Long_Parliament
# Added 345 links
# extracting /wiki/Laurent_Nkunda
# Added 112 links
# extracting /wiki/Tool
# Added 1022 links
# extracting /wiki/Bob_Knight
# Added 1649 links
# extracting /wiki/White_Coats_for_Black_Lives
# Added 369 links
# extracting /wiki/Casa_Ricordi
# Added 135 links
# extracting /wiki/Tony_Cloninger
# Added 306 links
# extracting /wiki/Savings_bank
# Added 586 links
# extracting /wiki/Top_Secret_Drum_Corps
# Added 34 links
# extracting /wiki/R280_highway_(Russia)
# Added 567 links
# extracting /wiki/Economic_history_of_France
# Added 678 links
# extracting /wiki/Alma_Adams
# Added 782 links
# extracting /wiki/Antigua_and_Barbuda
# Added 1269 links
# extracting /wiki/20th_Guards_Combined_Arms_Army
# Added 263 links
# extracting /wiki/Hanna_Reitsch
# Added 284 links
# extracting /wiki/Wexford_(Marshall,_Virginia)
# Added 249 links
# extracting /wiki/Social_Democratic_Party_(Romania)
# Added 1152 links
# extracting /wiki/1996_Romanian_local_elections
# Added 112 links
# extracting /wiki/Adelbert_Ames_Jr.
# Added 87 links
# extracting /wiki/Gateway_National_Recreation_Area
# Added 1015 links
# extracting /wiki/Parul_Sehgal
# Added 40 links
# extracting /wiki/Kanbun
# Added 335 links
# extracting /wiki/Head_of_state
# Added 2686 links
# extracting /wiki/Canton_of_Graub%C3%BCnden
# Added 741 links
# extracting /wiki/Association_of_World_Election_Bodies
# Added 210 links
# extracting /wiki/Zhangjiakou%E2%80%93Hohhot_dialect
# Added 438 links
# extracting /wiki/Battle_of_Sufa
# Added 696 links
# extracting /wiki/Repoblaci%C3%B3n_art_and_architecture
# Added 702 links
# extracting /wiki/Singalila_National_Park
# Added 475 links
# extracting /wiki/WPBS-TV
# Added 472 links
# extracting /wiki/Jeffrey_Meyers
# Added 69 links
# extracting /wiki/Krasnodar_Krai
# Added 533 links
# extracting /wiki/Barrio_Logan
# Added 172 links
# extracting /wiki/D%C3%A1il_%C3%89ireann_(Irish_Republic)
# Added 386 links
# extracting /wiki/French_Navy
# Added 784 links
# extracting /wiki/Tehran_Conference
# Added 777 links
# extracting /wiki/Dizengoff_Street_bus_bombing
# Added 83 links
# extracting /wiki/Refuge_Mont-Blanc
# Added 7 links
# extracting /wiki/Isabel_Mendes_Lopes
# Added 51 links
# extracting /wiki/WJPX
# Added 500 links
# extracting /wiki/Gilbert_and_Marshall_Islands_campaign
# Added 661 links
# extracting /wiki/NCIS_(TV_series)
# Added 800 links
# extracting /wiki/Promise_Me,_Dad
# Added 399 links
# extracting /wiki/June_8
# Added 1105 links
# extracting /wiki/Tunisian_collaborative_painting
# Added 540 links
# extracting /wiki/Arms_race
# Added 596 links
# extracting /wiki/2020s_in_military_history
# Added 601 links
# extracting /wiki/China_and_the_United_Nations
# Added 2126 links
# extracting /wiki/Belarusian_involvement_in_the_Russian_invasion_of_Ukraine
# Added 1092 links
# extracting /wiki/Bill_Vukovich
# Added 429 links
# extracting /wiki/1864_Romanian_constitutional_referendum
# Added 102 links
# extracting /wiki/City_(Minnesota)
# Added 1142 links
# extracting /wiki/Congo_River_Alliance
# Added 44 links
# extracting /wiki/Cesar_Chavez
# Added 744 links
# extracting /wiki/Grunge#Graphic_design
# Added 1392 links
# extracting /wiki/Coalition_forces_of_the_Napoleonic_Wars
# Added 107 links
# extracting /wiki/Minako_Honda
# Added 100 links
# extracting /wiki/Benjamin_Crump
# Added 564 links
# extracting /wiki/Donovan_Bailey
# Added 948 links
# extracting /wiki/Frozen_conflict
# Added 1018 links
# extracting /wiki/Larry_Miller_(basketball_player)
# Added 291 links
# extracting /wiki/Palestinian_enclaves
# Added 631 links
# extracting /wiki/Zulfikar_Ali_Bhutto
# Added 1263 links
# extracting /wiki/NOAA
# Added 2235 links
# extracting /wiki/Wheaton,_Minnesota
# Added 190 links
# extracting /wiki/Antipope_Clement_III
# Added 736 links
# extracting /wiki/BET_Jams
# Added 815 links
# extracting /wiki/The_Canadian_Encyclopedia
# Added 275 links
# extracting /wiki/WXBU
# Added 363 links
# extracting /wiki/Five_Eyes
# Added 2044 links
# extracting /wiki/Banpo
# Added 516 links
# extracting /wiki/William_Bonaparte-Wyse
# Added 76 links
# extracting /wiki/Bill_Adam
# Added 29 links
# extracting /wiki/Sudanese_Journalists_Syndicate
# Added 21 links
# extracting /wiki/April_19
# Added 1104 links
# extracting /wiki/Suriname
# Added 1199 links
# extracting /wiki/Radioactive
# Added 694 links
# extracting /wiki/Reliefweb
# Added 175 links
# extracting /wiki/WJAC-TV
# Added 592 links
# extracting /wiki/K-pop
# Added 1117 links
# extracting /wiki/Ufa
# Added 635 links
# extracting /wiki/Ma%C5%82gorzata_Foremniak
# Added 10 links
# extracting /wiki/2018_Summer_Youth_Olympics
# Added 1209 links
# extracting /wiki/Jen_Calleja
# Added 28 links
# extracting /wiki/WNLO_(TV)
# Added 1134 links
# extracting /wiki/Pitmatic
# Added 157 links
# extracting /wiki/Hurricane_Eta
# Added 573 links
# extracting /wiki/Huili
# Added 259 links
# extracting /wiki/Department_of_the_Interior
# Added 221 links
# extracting /wiki/Ezra_Pound_(Lewis)
# Added 90 links
# extracting /wiki/Reinsurance_Group_of_America
# Added 476 links
# extracting /wiki/Blockout_2024
# Added 485 links
# extracting /wiki/Supreme_Council_(Transnistria)
# Added 436 links
# extracting /wiki/White_Nile_State
# Added 52 links
# extracting /wiki/Mru_language#Script
# Added 909 links
# extracting /wiki/Magic_8_Ball
# Added 147 links
# extracting /wiki/Constitution_of_South_Korea
# Added 239 links
# extracting /wiki/Hollywood,_Florida
# Added 753 links
# extracting /wiki/HTML_Working_Group
# Added 160 links
# extracting /wiki/Ernie_Carroll
# Added 25 links
# extracting /wiki/Union_Station_(Kansas_City)
# Added 309 links
# extracting /wiki/Karl_B%C3%BChler
# Added 56 links
# extracting /wiki/2023_Israeli_female_tank_crew_fight
# Added 723 links
# extracting /wiki/Keith_Comstock
# Added 56 links
# extracting /wiki/Auschwitz
# Added 1364 links
# extracting /wiki/Torpedo
# Added 749 links
# extracting /wiki/Courier_Dover_Publications
# Added 45 links
# extracting /wiki/Henrietta_of_Nassau-Weilburg
# Added 174 links
# extracting /wiki/Edward_Elgar
# Added 878 links
# extracting /wiki/Clyde_Bellecourt
# Added 134 links
# extracting /wiki/2008_Nord-Kivu_campaign
# Added 652 links
# extracting /wiki/Telemundo
# Added 1450 links
# extracting /wiki/Dibebad
# Added 16 links
# extracting /wiki/Henry_Bumstead
# Added 633 links
# extracting /wiki/Estonia_in_the_Eurovision_Song_Contest_2001
# Added 233 links
# extracting /wiki/Founding_fathers_of_the_European_Union
# Added 430 links
# extracting /wiki/Danube_Delta
# Added 430 links
# extracting /wiki/Byzantine_art
# Added 1116 links
# extracting /wiki/Confucius
# Added 1820 links
# extracting /wiki/George_Gray_(television_personality)
# Added 44 links
# extracting /wiki/Christian_right
# Added 4034 links
# extracting /wiki/Jack_Stewart_(ice_hockey)
# Added 144 links
# extracting /wiki/Destiny_(singer)
# Added 743 links
# extracting /wiki/The_New_Yorker
# Added 569 links
# extracting /wiki/Maximilian_Schell
# Added 734 links
# extracting /wiki/Kazi_Nazrul_Islam
# Added 954 links
# extracting /wiki/Syria_Vilayet
# Added 170 links
# extracting /wiki/Avanguardia_Giovanile_Fascista
# Added 4 links
# extracting /wiki/1976
# Added 2318 links
# extracting /wiki/Battle_of_Taierzhuang
# Added 282 links
# extracting /wiki/Neolithic_symbols_in_China
# Added 200 links
# extracting /wiki/Barbara_St%C3%B6ckl
# Added 10 links
# extracting /wiki/2020_in_computing
# Added 1832 links
# extracting /wiki/Felleries
# Added 676 links
# extracting /wiki/Liz_McColgan
# Added 820 links
# extracting /wiki/Generalmajor
# Added 179 links
# extracting /wiki/Alamogordo_Bombing_and_Gunnery_Range
# Added 394 links
# extracting /wiki/Brukhin
# Added 78 links
# extracting /wiki/2nd_Standing_Committee_of_the_Workers%27_Party_of_Korea
# Added 213 links
# extracting /wiki/Islamic_State_in_the_Greater_Sahara
# Added 710 links
# extracting /wiki/Booth_Tarkington
# Added 419 links
# extracting /wiki/Ohio
# Added 1992 links
# extracting /wiki/Chess_Records
# Added 379 links
# extracting /wiki/Hamza_(rapper)
# Added 84 links
# extracting /wiki/June_1953
# Added 439 links
# extracting /wiki/Hofburg#Festival_Hall_Wing
# Added 223 links
# extracting /wiki/Geraint_Thomas
# Added 1731 links
# extracting /wiki/Flat_design
# Added 58 links
# extracting /wiki/Salta
# Added 198 links
# extracting /wiki/CBS_Television_Distribution
# Added 679 links
# extracting /wiki/Yan_Lianke
# Added 65 links
# extracting /wiki/Irish_Republican
# Added 2104 links
# extracting /wiki/Public_transport
# Added 769 links
# extracting /wiki/Fulco_Ruffo_di_Calabria
# Added 100 links
# extracting /wiki/2020s_in_climate_history
# Added 49 links
# extracting /wiki/Hunnic_art
# Added 174 links
# extracting /wiki/T%C3%AAte_Rousse_Hut
# Added 201 links
# extracting /wiki/August
# Added 973 links
# extracting /wiki/Choe_Ik-gyu
# Added 96 links
# extracting /wiki/Benny_Gantz
# Added 600 links
# extracting /wiki/May_2019
# Added 1870 links
# extracting /wiki/Gwynne_Gilford
# Added 27 links
# extracting /wiki/Robert_Morse
# Added 738 links
# extracting /wiki/English_in_Barbados
# Added 381 links
# extracting /wiki/Bob_Kroll_(police_officer)
# Added 77 links
# extracting /wiki/United_Nations_Office_at_Vienna
# Added 288 links
# extracting /wiki/Narcissistic_personality_disorder
# Added 701 links
# extracting /wiki/Krasnogorsk,_Moscow_Oblast
# Added 270 links
# extracting /wiki/Dimitrovgrad,_Russia
# Added 150 links
# extracting /wiki/1888
# Added 1123 links
# extracting /wiki/Giovanni_Gentile
# Added 2802 links
# extracting /wiki/Middle_Kingdom_of_Egypt
# Added 351 links
# extracting /wiki/Don_Torcuato
# Added 181 links
# extracting /wiki/Practising_Law_Institute
# Added 12 links
# extracting /wiki/Omidyar_Network
# Added 45 links
# extracting /wiki/Jefferson_Parish,_Louisiana
# Added 452 links
# extracting /wiki/November_2015
# Added 868 links
# extracting /wiki/Christine_Buchegger
# Added 34 links
# extracting /wiki/China%E2%80%93Sudan_relations
# Added 353 links
# extracting /wiki/Twin_Cities
# Added 1601 links
# extracting /wiki/Superpower
# Added 532 links
# extracting /wiki/December_1951
# Added 1900 links
# extracting /wiki/Muskegon,_Michigan
# Added 870 links
# extracting /wiki/1988
# Added 1485 links
# extracting /wiki/Amtrak_Police_Department
# Added 168 links
# extracting /wiki/Br%C3%AAmes
# Added 920 links
# extracting /wiki/Elective_monarchy
# Added 912 links
# extracting /wiki/Grupo_Cine_Liberaci%C3%B3n
# Added 536 links
# extracting /wiki/Latvia_in_the_Eurovision_Song_Contest_2002
# Added 192 links
# extracting /wiki/WNL_(broadcaster)
# Added 348 links
# extracting /wiki/War_in_Dagestan_(1999)
# Added 859 links
# extracting /wiki/Karnei_Shomron_Mall_suicide_bombing
# Added 278 links
# extracting /wiki/Viceroyalty_of_the_R%C3%ADo_de_la_Plata
# Added 755 links
# extracting /wiki/Metrobus_Sur
# Added 164 links
# extracting /wiki/Walter_Hampden
# Added 94 links
# extracting /wiki/U.S._Route_40_in_Missouri
# Added 385 links
# extracting /wiki/Mediterranean_and_Middle_East_theatre_of_World_War_II
# Added 1186 links
# extracting /wiki/Jonathan_Cape
# Added 299 links
# extracting /wiki/CTV_News_Channel_(Canadian_TV_channel)
# Added 346 links
# extracting /wiki/French_Fourth_Republic
# Added 612 links
# extracting /wiki/2024_Ivanovo_Ilyushin_Il-76_crash
# Added 68 links
# extracting /wiki/Robert_Reich
# Added 786 links
# extracting /wiki/Erki_P%C3%BCtsep
# Added 64 links
# extracting /wiki/Saintonge_War
# Added 157 links
# extracting /wiki/Alsace
# Added 1011 links
# extracting /wiki/Arthur_Schnitzler
# Added 149 links
# extracting /wiki/Israelis
# Added 848 links
# extracting /wiki/Psychogeography
# Added 888 links
# extracting /wiki/Lost_Generation
# Added 241 links
# extracting /wiki/Little_Ships_of_Dunkirk
# Added 655 links
# extracting /wiki/Killing_of_Muhammad_al-Durrah
# Added 646 links
# extracting /wiki/Battle_of_Raab
# Added 581 links
# extracting /wiki/Austria_in_the_Eurovision_Song_Contest_2021
# Added 359 links
# extracting /wiki/Mont_Blanc_du_Tacul
# Added 219 links
# extracting /wiki/Truman_Doctrine
# Added 1228 links
# extracting /wiki/President_of_Greece
# Added 1154 links
# extracting /wiki/2020_in_Mali
# Added 159 links
# extracting /wiki/Timeline_of_World_War_II_(1945)
# Added 828 links
# extracting /wiki/Austria_in_the_Eurovision_Song_Contest_1966
# Added 572 links
# extracting /wiki/Mikhail_Mishustin
# Added 1310 links
# extracting /wiki/Conversations-Lexikon_mit_vorz%C3%BCglicher_R%C3%BCcksicht_auf_die_gegenw%C3%A4rtigen_Zeiten
# Added 8 links
# extracting /wiki/La_Paternal,_Buenos_Aires
# Added 87 links
# extracting /wiki/Zimbabwean_English
# Added 694 links
# extracting /wiki/Sirindhorn
# Added 902 links
# extracting /wiki/Enrico_Corradini
# Added 1813 links
# extracting /wiki/Great_Dismal_Swamp_maroons
# Added 564 links
# extracting /wiki/Fran%C3%A7ois_G%C3%A9rard
# Added 114 links
# extracting /wiki/Nichifor_Crainic
# Added 168 links
# extracting /wiki/Invasion_of_Poland
# Added 1561 links
# extracting /wiki/United_Kingdom_in_the_Eurovision_Song_Contest
# Added 1727 links
# extracting /wiki/Dede_(artist)
# Added 31 links
# extracting /wiki/Samuel_Little
# Added 165 links
# extracting /wiki/Syria%E2%80%93Lebanon_campaign
# Added 1239 links
# extracting /wiki/Antonov_An-26
# Added 661 links
# extracting /wiki/Siege_of_Bellegarde_(1793)
# Added 505 links
# extracting /wiki/Marie_Jepsen
# Added 29 links
# extracting /wiki/Oracle
# Added 415 links
# extracting /wiki/Russian-occupied_territories_of_Ukraine
# Added 1793 links
# extracting /wiki/Deaths_in_April_2021
# Added 2609 links
# extracting /wiki/Israel_Abrahams
# Added 35 links
# extracting /wiki/The_Oxford_History_of_the_French_Revolution
# Added 48 links
# extracting /wiki/Jon_Batiste
# Added 1546 links
# extracting /wiki/Curtis_Keeble
# Added 50 links
# extracting /wiki/Mathieu_Kassovitz
# Added 350 links
# extracting /wiki/Aestheticism
# Added 810 links
# extracting /wiki/Jew
# Added 2202 links
# extracting /wiki/Under_the_Eye_of_the_Big_Bird
# Added 19 links
# extracting /wiki/Sun_Myung_Moon
# Added 686 links
# extracting /wiki/H-dropping
# Added 242 links
# extracting /wiki/Jean_Cruppi
# Added 454 links
# extracting /wiki/Grand_Rounds_National_Scenic_Byway
# Added 148 links
# extracting /wiki/Victoria_Brownworth
# Added 104 links
# extracting /wiki/Interstate_10_in_California
# Added 647 links
# extracting /wiki/Eurovision_Song_Contest_1980
# Added 778 links
# extracting /wiki/2020_in_Brunei
# Added 97 links
# extracting /wiki/Output_(economics)
# Added 117 links
# extracting /wiki/December_26
# Added 1258 links
# extracting /wiki/Supplemental_Nutrition_Assistance_Program#Pilot_Food_Stamp_Program_(1961–1964)
# Added 513 links
# extracting /wiki/Trademark
# Added 312 links
# extracting /wiki/Photorealism
# Added 687 links
# extracting /wiki/Karelian_Isthmus
# Added 614 links
# extracting /wiki/Maresville
# Added 916 links
# extracting /wiki/African-American_self-determination
# Added 623 links
# extracting /wiki/COVID-19_pandemic_in_Asia
# Added 2140 links
# extracting /wiki/January_1958
# Added 757 links
# extracting /wiki/Brooklyn_Community_Board_16
# Added 208 links
# extracting /wiki/Condette
# Added 913 links
# extracting /wiki/Antonio_%C3%81lvarez_Jonte
# Added 44 links
# extracting /wiki/Fortuna_Sittard
# Added 909 links
# extracting /wiki/Salah_Khalaf
# Added 94 links
# extracting /wiki/Gotham_Book_Mart
# Added 656 links
# extracting /wiki/Third_siege_of_Girona_(Peninsular_War)
# Added 506 links
# extracting /wiki/January_2018_United_States_federal_government_shutdown
# Added 598 links
# extracting /wiki/Killing_of_Mansur_Ball-Bey
# Added 390 links
# extracting /wiki/League_of_Saint_George
# Added 304 links
# extracting /wiki/Progressive_Era
# Added 2152 links
# extracting /wiki/Milky_Way_(chocolate_bar)
# Added 131 links
# extracting /wiki/German_prisoners_of_war_in_the_United_States
# Added 896 links
# extracting /wiki/Bettignies
# Added 668 links
# extracting /wiki/Second_Cold_War
# Added 1309 links
# extracting /wiki/Paran%C3%A1,_Entre_R%C3%ADos
# Added 168 links
# extracting /wiki/Tom_Cavanagh
# Added 232 links
# extracting /wiki/Worldvision_Enterprises
# Added 622 links
# extracting /wiki/University_of_California_Riverside
# Added 716 links
# extracting /wiki/Montenotte_campaign
# Added 280 links
# extracting /wiki/Sharada_script
# Added 743 links
# extracting /wiki/January_1963_lunar_eclipse
# Added 498 links
# extracting /wiki/Henri_Malo
# Added 7 links
# extracting /wiki/Korean_idol
# Added 214 links
# extracting /wiki/Alice_Tumler
# Added 52 links
# extracting /wiki/CBS_Films
# Added 1057 links
# extracting /wiki/Letizia_Ramolino
# Added 259 links
# extracting /wiki/2017_Shayrat_missile_strike
# Added 1833 links
# extracting /wiki/Prisoners_of_war_in_the_Russian_invasion_of_Ukraine
# Added 1157 links
# extracting /wiki/Origyn_Web_Browser
# Added 325 links
# extracting /wiki/Quotation
# Added 293 links
# extracting /wiki/Kareem_McKenzie
# Added 247 links
# extracting /wiki/Literature_in_Poland
# Added 898 links
# extracting /wiki/Jimmy_Walker
# Added 342 links
# extracting /wiki/Videotelephony
# Added 829 links
# extracting /wiki/Greek_Braille
# Added 294 links
# extracting /wiki/Andrew_Jordan_(racing_driver)
# Added 767 links
# extracting /wiki/Home_Rule_Act_1914
# Added 525 links
# extracting /wiki/Siege_of_Mariupol
# Added 1432 links
# extracting /wiki/Rian_Wallace
# Added 122 links
# extracting /wiki/Israeli_hostage_deal_protests
# Added 238 links
# extracting /wiki/Katihar%E2%80%93Siliguri_line
# Added 478 links
# extracting /wiki/Citation_of_United_Kingdom_legislation
# Added 82 links
# extracting /wiki/Nicktoons_(Middle_Eastern_and_North_African_TV_channel)
# Added 966 links
# extracting /wiki/Eurovision_Song_Contest_winners
# Added 1396 links
# extracting /wiki/William_I_of_the_Netherlands
# Added 813 links
# extracting /wiki/Belgium_in_the_Eurovision_Song_Contest
# Added 1234 links
# extracting /wiki/Renty
# Added 917 links
# extracting /wiki/Death_of_Ronald_Greene
# Added 409 links
# extracting /wiki/LTV1
# Added 574 links
# extracting /wiki/Adobe_Inc.
# Added 911 links
# extracting /wiki/Aiguille_des_Grands_Montets
# Added 198 links
# extracting /wiki/Alberto_Ginastera
# Added 201 links
# extracting /wiki/IMDb_(identifier)
# Added 348 links
# extracting /wiki/Third_World
# Added 322 links
# extracting /wiki/Eric_Dingwall
# Added 73 links
# extracting /wiki/Warluzel
# Added 914 links
# extracting /wiki/FuboTV
# Added 476 links
# extracting /wiki/Israeli_torture_in_the_occupied_territories
# Added 226 links
# extracting /wiki/October_2024_Rufaida_school_attack
# Added 655 links
# extracting /wiki/Festubert
# Added 915 links
# extracting /wiki/April_29
# Added 1366 links
# extracting /wiki/Vienna_State_Opera
# Added 476 links
# extracting /wiki/Order_of_Saint_Ferdinand_and_of_Merit
# Added 60 links
# extracting /wiki/Bharati_Mukherjee
# Added 76 links
# extracting /wiki/Bert_Eriksson
# Added 310 links
# extracting /wiki/Transjordan_(region)
# Added 301 links
# extracting /wiki/George_Steinbrenner
# Added 612 links
# extracting /wiki/%C3%89lections_Qu%C3%A9bec
# Added 23 links
# extracting /wiki/Lac_qui_Parle_County,_Minnesota
# Added 445 links
# extracting /wiki/AD_1948
# Added 2801 links
# extracting /wiki/Guillaume-Mathieu_Dumas
# Added 67 links
# extracting /wiki/Music_of_Jordan
# Added 116 links
# extracting /wiki/Patrick_M._Walsh
# Added 165 links
# extracting /wiki/Hardinghen
# Added 910 links
# extracting /wiki/International_Brigades
# Added 989 links
# extracting /wiki/Free_Ai_Weiwei_street_art_campaign
# Added 97 links
# extracting /wiki/Mughal_art
# Added 527 links
# extracting /wiki/North_East_Games
# Added 17 links
# extracting /wiki/Arte_Informale
# Added 40 links
# extracting /wiki/Vladim%C3%ADr_%C5%A0micer
# Added 319 links
# extracting /wiki/List_of_public_art_in_Los_Angeles#Central_Los_Angeles
# Added 416 links
# extracting /wiki/Berazategui
# Added 169 links
# extracting /wiki/Metrobus_9_de_Julio
# Added 161 links
# extracting /wiki/2020_in_the_Dominican_Republic
# Added 133 links
# extracting /wiki/Biennale
# Added 333 links
# extracting /wiki/December_8
# Added 1357 links
# extracting /wiki/Lunfardo
# Added 453 links
# extracting /wiki/AD_1954
# Added 1945 links
# extracting /wiki/Illinois_Route_37
# Added 160 links
# extracting /wiki/IFPI_Norge
# Added 359 links
# extracting /wiki/The_Battle_of_Hohenlinden
# Added 25 links
# extracting /wiki/Sturgis,_South_Dakota
# Added 569 links
# extracting /wiki/Julius_Rosenwald
# Added 113 links
# extracting /wiki/Leopold_Museum
# Added 44 links
# extracting /wiki/History_of_Tallahassee,_Florida#Black_history
# Added 512 links
# extracting /wiki/Hassan_Yousef_(Hamas_leader)
# Added 424 links
# extracting /wiki/Independent_Foreign_Fiction_Prize
# Added 511 links
# extracting /wiki/Pskov
# Added 462 links
# extracting /wiki/April_5
# Added 1845 links
# extracting /wiki/Death_and_state_funeral_of_Kim_Il_Sung
# Added 200 links
# extracting /wiki/Arabian_Peninsula
# Added 958 links
# extracting /wiki/Canadian_Broadcasting_Corporation
# Added 1366 links
# extracting /wiki/Albert_of_Saxe-Teschen
# Added 143 links
# extracting /wiki/American_Privacy_Rights_Act
# Added 92 links
# extracting /wiki/Gateway_Arch
# Added 419 links
# extracting /wiki/2015%E2%80%932016_wave_of_violence_in_the_Israeli%E2%80%93Palestinian_conflict
# Added 550 links
# extracting /wiki/Ernesto_Fernandes
# Added 13 links
# extracting /wiki/Donetsk_Oblast
# Added 389 links
# extracting /wiki/Archduke_Sigismund_of_Austria_(1826%E2%80%931891)
# Added 163 links
# extracting /wiki/Chamber_for_Workers_and_Employees
# Added 16 links
# extracting /wiki/Missionary
# Added 1576 links
# extracting /wiki/Binod_Chaudhary
# Added 64 links
# extracting /wiki/Patrick_Muyaya_Katembwe
# Added 22 links
# extracting /wiki/2023_State_of_the_Union_Address
# Added 886 links
# extracting /wiki/July_12
# Added 1205 links
# extracting /wiki/Margaret_Mead
# Added 882 links
# extracting /wiki/Factional_violence_in_Libya_(2011%E2%80%932014)
# Added 768 links
# extracting /wiki/Pan-African_Congress
# Added 586 links
# extracting /wiki/%C3%89douard_Adolphe_Casimir_Joseph_Mortier
# Added 801 links
# extracting /wiki/Denys_Kireyev
# Added 827 links
# extracting /wiki/Marconnelle
# Added 910 links
# extracting /wiki/Austria_in_the_Eurovision_Young_Dancers
# Added 306 links
# extracting /wiki/Rashtriya_Sikh_Sangat
# Added 325 links
# extracting /wiki/Slava_Ukraini#Russian_invasion_of_Ukraine
# Added 1000 links
# extracting /wiki/Idol_Gives_Back
# Added 531 links
# extracting /wiki/Holy_Land
# Added 690 links
# extracting /wiki/Giovanni_Papini
# Added 140 links
# extracting /wiki/Argentina_during_World_War_II
# Added 674 links
# extracting /wiki/Stewart_Francke
# Added 14 links
# extracting /wiki/Ostinato
# Added 376 links
# extracting /wiki/Twelve-tone_technique
# Added 437 links
# extracting /wiki/Louis_Menand
# Added 99 links
# extracting /wiki/Marseille
# Added 1470 links
# extracting /wiki/Agriculture_in_Romania
# Added 230 links
# extracting /wiki/T%C3%A9l%C3%A9diffusion_d%27Alg%C3%A9rie
# Added 307 links
# extracting /wiki/WHAM-TV
# Added 811 links
# extracting /wiki/Blockade_of_Germany_(1939%E2%80%931945)
# Added 1286 links
# extracting /wiki/Argenti%C3%A8re_Hut
# Added 203 links
# extracting /wiki/National_Register_of_Historic_Places_listings_in_Lexington,_Massachusetts
# Added 111 links
# extracting /wiki/David_S._Painter
# Added 591 links
# extracting /wiki/John_Rubinstein
# Added 388 links
# extracting /wiki/T._Tileston_Wells
# Added 160 links
# extracting /wiki/Nausica%C3%A4_Centre_National_de_la_Mer
# Added 74 links
# extracting /wiki/Guwahati
# Added 814 links
# extracting /wiki/Martyn_Lyons
# Added 6 links
# extracting /wiki/Oberkommando_der_Wehrmacht
# Added 294 links
# extracting /wiki/Geography_of_Wisconsin
# Added 431 links
# extracting /wiki/Michael_Baden
# Added 127 links
# extracting /wiki/Manila_massacre#Mass_rapes
# Added 622 links
# extracting /wiki/Agriculture
# Added 1341 links
# extracting /wiki/Legislature
# Added 740 links
# extracting /wiki/Ful_medames
# Added 455 links
# extracting /wiki/Order_of_the_Southern_Cross
# Added 664 links
# extracting /wiki/Saint_Fergil
# Added 131 links
# extracting /wiki/Bouvignies
# Added 671 links
# extracting /wiki/Barthelemy_Catherine_Joubert
# Added 174 links
# extracting /wiki/Radiodiffusion-T%C3%A9l%C3%A9vision_Fran%C3%A7aise
# Added 589 links
# extracting /wiki/Voiced_alveolar_lateral_approximant
# Added 840 links
# extracting /wiki/Hornaing
# Added 670 links
# extracting /wiki/Vosges
# Added 208 links
# extracting /wiki/People%27s_Deputy_of_Ukraine
# Added 294 links
# extracting /wiki/Annapurna_(mountain_range)
# Added 227 links
# extracting /wiki/Rape_of_Donetsk_People%27s_Republic_soldiers_by_Kadyrovites
# Added 1079 links
# extracting /wiki/Imipramine
# Added 3985 links
# extracting /wiki/Armed_Forces_of_the_Argentine_Republic
# Added 506 links
# extracting /wiki/Volkssozialistische_Bewegung_Deutschlands/Partei_der_Arbeit
# Added 393 links
# extracting /wiki/Sudan%E2%80%93United_States_relations
# Added 476 links
# extracting /wiki/Urban_warfare
# Added 568 links
# extracting /wiki/Wannehain
# Added 671 links
# extracting /wiki/Olive_oil
# Added 1016 links
# extracting /wiki/Bharatiya_Gau_Raksha_Dal
# Added 239 links
# extracting /wiki/Anglo-German_Naval_Agreement
# Added 139 links
# extracting /wiki/Bill_Shorten
# Added 587 links
# extracting /wiki/Oyo_State_coup_attempt
# Added 394 links
# extracting /wiki/Constantius_Chlorus
# Added 909 links
# extracting /wiki/Juche
# Added 686 links
# extracting /wiki/Mediterranean_Sea
# Added 1862 links
# extracting /wiki/Permanent_Representative_of_France_to_the_United_Nations
# Added 131 links
# extracting /wiki/Yolanda_King
# Added 389 links
# extracting /wiki/Repsol-YPF_Tower
# Added 33 links
# extracting /wiki/Brebi%C3%A8res
# Added 919 links
# extracting /wiki/Enrico_De_Nicola
# Added 211 links
# extracting /wiki/Wattignies
# Added 781 links
# extracting /wiki/December_1
# Added 1297 links
# extracting /wiki/Indo-Persian_culture
# Added 395 links
# extracting /wiki/1997_Asian_financial_crisis
# Added 1445 links
# extracting /wiki/Noshaq
# Added 94 links
# extracting /wiki/Wang_Huning
# Added 1252 links
# extracting /wiki/Republikanischer_Schutzbund
# Added 303 links
# extracting /wiki/Operation_Gladio
# Added 937 links
# extracting /wiki/Franco_Freda
# Added 1704 links
# extracting /wiki/Pylyp_Orlyk
# Added 154 links
# extracting /wiki/Brian_Boitano
# Added 848 links
# extracting /wiki/Roman_Empire
# Added 3663 links
# extracting /wiki/Operation_Himmler
# Added 168 links
# extracting /wiki/Radiotelevizija_Slovenija
# Added 434 links
# extracting /wiki/Standard_Singaporean_Mandarin
# Added 384 links
# extracting /wiki/Moyenneville,_Pas-de-Calais
# Added 907 links
# extracting /wiki/Craighead_County,_Arkansas
# Added 441 links
# extracting /wiki/Democratic_Party_(United_States)
# Added 2487 links
# extracting /wiki/Eldon_Griffiths
# Added 76 links
# extracting /wiki/Neil_Bush
# Added 141 links
# extracting /wiki/Wuchereria_bancrofti
# Added 234 links
# extracting /wiki/Halld%C3%B3r_Laxness
# Added 402 links
# extracting /wiki/Bison_hunting
# Added 558 links
# extracting /wiki/Dave_Alvin
# Added 193 links
# extracting /wiki/Amman_Bus_Rapid_Transit
# Added 25 links
# extracting /wiki/Telecommunications_in_North_Korea
# Added 192 links
# extracting /wiki/Bar_(unit)
# Added 87 links
# extracting /wiki/Satellite_state
# Added 317 links
# extracting /wiki/Heinrich_M%C3%BCller_(Gestapo)
# Added 322 links
# extracting /wiki/Sture_Murders
# Added 75 links
# extracting /wiki/List_of_diseases_eliminated_from_the_United_States
# Added 81 links
# extracting /wiki/Santa_Fe,_Argentina
# Added 199 links
# extracting /wiki/Cairo,_Illinois
# Added 538 links
# extracting /wiki/Symbolism_in_the_French_Revolution
# Added 522 links
# extracting /wiki/TMF_(UK_%26_Ireland)
# Added 218 links
# extracting /wiki/April_1947
# Added 471 links
# extracting /wiki/1996_Israeli_general_election
# Added 339 links
# extracting /wiki/East_Coast_of_the_United_States
# Added 1169 links
# extracting /wiki/Milwaukee_Art_Museum
# Added 201 links
# extracting /wiki/Todd_Rokita
# Added 875 links
# extracting /wiki/Sputnik_V
# Added 2279 links
# extracting /wiki/Pernes-l%C3%A8s-Boulogne
# Added 910 links
# extracting /wiki/Commissioner_of_Health_of_the_City_of_New_York
# Added 160 links
# extracting /wiki/L%C3%A9on_Spilliaert
# Added 37 links
# extracting /wiki/Obies
# Added 674 links
# extracting /wiki/The_Signpost
# Added 223 links
# extracting /wiki/St._Rupert%27s_Church,_Vienna
# Added 32 links
# extracting /wiki/Goodyear_Tire_%26_Rubber_Company
# Added 978 links
# extracting /wiki/Chairman_and_Vice_Chairman_of_the_Workers%27_Party_of_Korea#Chairmen
# Added 202 links
# extracting /wiki/Millennium_Square,_Leeds
# Added 294 links
# extracting /wiki/United_Nations_Mission_in_Sudan
# Added 662 links
# extracting /wiki/Nanyang_Style
# Added 151 links
# extracting /wiki/Dardanelles
# Added 751 links
# extracting /wiki/KN-25
# Added 155 links
# extracting /wiki/Government_of_Brunei
# Added 240 links
# extracting /wiki/November_3
# Added 1325 links
# extracting /wiki/Portugal_in_the_Eurovision_Song_Contest_2017
# Added 532 links
# extracting /wiki/Guerrilla_art
# Added 101 links
# extracting /wiki/Anton_Hur
# Added 65 links
# extracting /wiki/Jonathan_Turley
# Added 268 links
# extracting /wiki/Sepsis
# Added 1053 links
# extracting /wiki/Business_Insider
# Added 111 links
# extracting /wiki/Fad%C3%A9la_M%27rabet
# Added 9 links
# extracting /wiki/Brooklyn%E2%80%93Queens_Expressway
# Added 550 links
# extracting /wiki/Indirect_approach
# Added 15 links
# extracting /wiki/November_1950
# Added 543 links
# extracting /wiki/Aveiro_District
# Added 161 links
# extracting /wiki/ERTT
# Added 312 links
# extracting /wiki/Wrongful_death_lawsuit
# Added 46 links
# extracting /wiki/Grand_Duchy_of_Oldenburg
# Added 202 links
# extracting /wiki/Killing_of_Samuel_DuBose
# Added 467 links
# extracting /wiki/Pronville-en-Artois
# Added 906 links
# extracting /wiki/C._W._A._Scott
# Added 246 links
# extracting /wiki/Holding_a_Black_Lives_Matter_Sign_in_America%27s_Most_Racist_Town
# Added 411 links
# extracting /wiki/2024_Moscow_Victory_Day_Parade
# Added 956 links
# extracting /wiki/Hanns_Joachim_Friedrichs
# Added 19 links
# extracting /wiki/James_F._Rooney
# Added 102 links
# extracting /wiki/End-to-end_encryption
# Added 233 links
# extracting /wiki/Freedom_of_religion_in_Austria
# Added 308 links
# extracting /wiki/Elias_Canetti
# Added 741 links
# extracting /wiki/Robert_Cecil,_1st_Earl_of_Salisbury
# Added 344 links
# extracting /wiki/Archbishop_of_Mainz
# Added 154 links
# extracting /wiki/William_Baziotes
# Added 43 links
# extracting /wiki/XForms
# Added 161 links
# extracting /wiki/Definitions_of_fascism
# Added 2087 links
# extracting /wiki/International_Gothic_art_in_Italy
# Added 815 links
# extracting /wiki/Gui-Jean-Baptiste_Target
# Added 474 links
# extracting /wiki/Chromosome
# Added 772 links
# extracting /wiki/Antarctica
# Added 1917 links
# extracting /wiki/Swiss_Standard_German
# Added 277 links
# extracting /wiki/Galway
# Added 934 links
# extracting /wiki/Night_writing
# Added 153 links
# extracting /wiki/Vacqueriette-Erqui%C3%A8res
# Added 907 links
# extracting /wiki/Dorinha_Duval
# Added 25 links
# extracting /wiki/Battles_of_Stockach_and_Engen
# Added 229 links
# extracting /wiki/Eddy_Ouwens
# Added 343 links
# extracting /wiki/Operation_Wilfred
# Added 849 links
# extracting /wiki/August_1937
# Added 434 links
# extracting /wiki/Spreitenbach
# Added 145 links
# extracting /wiki/World_Bank_Group
# Added 622 links
# extracting /wiki/Moreau,_New_York
# Added 407 links
# extracting /wiki/Paramount_Communications
# Added 2027 links
# extracting /wiki/German%E2%80%93Polish_declaration_of_non-aggression
# Added 128 links
# extracting /wiki/Leo_Slezak
# Added 97 links
# extracting /wiki/Chinese_folklore
# Added 110 links
# extracting /wiki/Marty_Gervais
# Added 17 links
# extracting /wiki/Free_Buryatia_Foundation
# Added 106 links
# extracting /wiki/The_Insider_(film)
# Added 363 links
# extracting /wiki/Benghazi
# Added 457 links
# extracting /wiki/Colectivo_92
# Added 44 links
# extracting /wiki/Pahonia_Regiment
# Added 868 links
# extracting /wiki/Tingry
# Added 904 links
# extracting /wiki/NHRA_U.S._Nationals
# Added 76 links
# extracting /wiki/3_November_1975_Bangladeshi_coup_d%27%C3%A9tat
# Added 155 links
# extracting /wiki/Paektusan_Secret_Camp
# Added 15 links
# extracting /wiki/Fran%C3%A7ois_Chabot
# Added 60 links
# extracting /wiki/Population_transfer_in_the_Soviet_Union
# Added 1299 links
# extracting /wiki/Victor_Davis_Hanson
# Added 835 links
# extracting /wiki/Louisiana_Voodoo
# Added 229 links
# extracting /wiki/Comuna_8
# Added 80 links
# extracting /wiki/1963_in_Brazil
# Added 302 links
# extracting /wiki/Robespierre
# Added 1986 links
# extracting /wiki/2020_in_science
# Added 2681 links
# extracting /wiki/2020_in_Algeria
# Added 184 links
# extracting /wiki/Copyright_troll
# Added 241 links
# extracting /wiki/Pope_Eleutherius
# Added 814 links
# extracting /wiki/Black_Lives_Matter_street_mural_(Cincinnati)
# Added 368 links
# extracting /wiki/List_of_monarchs_of_Korea
# Added 448 links
# extracting /wiki/October_1941
# Added 554 links
# extracting /wiki/Netta_Barzilai
# Added 706 links
# extracting /wiki/Variety_(magazine)
# Added 230 links
# extracting /wiki/British_Democratic_Party_(2013)
# Added 2223 links
# extracting /wiki/Hayley_Mills
# Added 663 links
# extracting /wiki/Great_Powers
# Added 193 links
# extracting /wiki/List_of_countries_and_dependencies_by_population_density
# Added 442 links
# extracting /wiki/Pontianak_Teochew
# Added 1485 links
# extracting /wiki/Lisbon_Airport
# Added 617 links
# extracting /wiki/Milan_Stojadinovi%C4%87
# Added 185 links
# extracting /wiki/The_Second_World_War_(book)
# Added 70 links
# extracting /wiki/Sans-culottes
# Added 570 links
# extracting /wiki/Julius_II
# Added 1316 links
# extracting /wiki/Chicago_White_Sox
# Added 1725 links
# extracting /wiki/Wahhabism
# Added 1724 links
# extracting /wiki/Champex
# Added 196 links
# extracting /wiki/Nightclub
# Added 720 links
# extracting /wiki/MetroLink_(St._Louis)
# Added 661 links
# extracting /wiki/Knopf_Doubleday_Publishing_Group
# Added 497 links
# extracting /wiki/Reformed_Christianity
# Added 2110 links
# extracting /wiki/Wet_season
# Added 234 links
# extracting /wiki/Epidemiology_of_syphilis
# Added 154 links
# extracting /wiki/Battle_of_Hohenlinden
# Added 688 links
# extracting /wiki/Medan_Hokkien
# Added 1417 links
# extracting /wiki/Carlos_Slim
# Added 335 links
# extracting /wiki/Diversity_of_tactics
# Added 148 links
# extracting /wiki/Abdullah_I_of_Jordan
# Added 278 links
# extracting /wiki/Friedrich_Joseph,_Count_of_Nauendorf
# Added 134 links
# extracting /wiki/Arena_rock
# Added 373 links
# extracting /wiki/Operation_Anthropoid
# Added 383 links
# extracting /wiki/October_29
# Added 1345 links
# extracting /wiki/Barry_Corbin
# Added 200 links
# extracting /wiki/Prime_Minister_of_Azerbaijan
# Added 621 links
# extracting /wiki/14th_Supreme_People%27s_Assembly
# Added 320 links
# extracting /wiki/Wheat_production_in_the_United_States
# Added 342 links
# extracting /wiki/Nobody_Is_Above_the_Law
# Added 272 links
# extracting /wiki/Hugh_Bonneville
# Added 350 links
# extracting /wiki/December
# Added 854 links
# extracting /wiki/First_Extraordinary_Session_of_the_Islamic_Summit_Conference
# Added 111 links
# extracting /wiki/Guerguerat
# Added 26 links
# extracting /wiki/World_Intellectual_Property_Organization
# Added 725 links
# extracting /wiki/Colonial_war
# Added 1786 links
# extracting /wiki/Michael_Broers
# Added 34 links
# extracting /wiki/Gram_Parsons
# Added 470 links
# extracting /wiki/Ministry_for_Foreign_Affairs_(Sweden)
# Added 422 links
# extracting /wiki/United_Nations_Security_Council_Resolution_2736
# Added 128 links
# extracting /wiki/Ah_Young
# Added 138 links
# extracting /wiki/El-Obeid
# Added 56 links
# extracting /wiki/US_Boulogne_C%C3%B4te_d%27Opale
# Added 315 links
# extracting /wiki/Kliptown
# Added 2083 links
# extracting /wiki/Electric_vehicle_battery
# Added 279 links
# extracting /wiki/Hamilton,_Bermuda
# Added 337 links
# extracting /wiki/National_Assembly_of_South_Africa
# Added 768 links
# extracting /wiki/Boardwalk_Empire_(season_3)
# Added 228 links
# extracting /wiki/Black_Lives_Matter_movement_in_popular_culture#Art
# Added 513 links
# extracting /wiki/Lists_of_office-holders
# Added 1049 links
# extracting /wiki/Madeleine_Sophie_Barat
# Added 78 links
# extracting /wiki/2023_Wagner_Group_plane_crash
# Added 1160 links
# extracting /wiki/List_of_United_States_cities_by_population
# Added 1232 links
# extracting /wiki/Necatoriasis
# Added 192 links
# extracting /wiki/East_Prussian_offensive
# Added 452 links
# extracting /wiki/Urban_neighbourhoods_of_Sudbury
# Added 175 links
# extracting /wiki/Enabling_Act_of_1933
# Added 513 links
# extracting /wiki/George_Floyd_protests_in_New_Jersey
# Added 300 links
# extracting /wiki/Gustav_Regler
# Added 25 links
# extracting /wiki/Piti%C3%A9-Salp%C3%AAtri%C3%A8re_Hospital
# Added 215 links
# extracting /wiki/Governor_of_Maryland
# Added 552 links
# extracting /wiki/Cleopa_Msuya
# Added 84 links
# extracting /wiki/Roberts,_Wisconsin
# Added 129 links
# extracting /wiki/Is-Serkin
# Added 16 links
# extracting /wiki/Abkhazia_conflict
# Added 717 links
# extracting /wiki/World_Wide_Web_Consortium#Working_draft_(WD)
# Added 272 links
# extracting /wiki/Childeric_III
# Added 190 links
# extracting /wiki/11th_Legislature_of_the_Third_Portuguese_Republic
# Added 61 links
# extracting /wiki/Nynorsk
# Added 550 links
# extracting /wiki/Line_infantry
# Added 98 links
# extracting /wiki/Bicycle_gearing
# Added 265 links
# extracting /wiki/M23_offensive_(2022%E2%80%93present)
# Added 1470 links
# extracting /wiki/Canton_of_Grande-Synthe
# Added 61 links
# extracting /wiki/Results_breakdown_of_the_2025_Portuguese_legislative_election
# Added 568 links
# extracting /wiki/Anders_Peter_Nielsen
# Added 17 links
# extracting /wiki/Quesques
# Added 903 links
# extracting /wiki/University_of_Alabama_at_Birmingham
# Added 408 links
# extracting /wiki/David_Jason
# Added 681 links
# extracting /wiki/Henri_Gr%C3%A9goire
# Added 579 links
# extracting /wiki/Nordicism
# Added 304 links
# extracting /wiki/Aleksandr_Karelin
# Added 400 links
# extracting /wiki/Sokhumi
# Added 1309 links
# extracting /wiki/Earl_Ofari_Hutchinson
# Added 54 links
# extracting /wiki/Executive_Order_10925
# Added 191 links
# extracting /wiki/Archduke_Wenceslaus_of_Austria
# Added 246 links
# extracting /wiki/Jim_Smith_(animator)
# Added 69 links
# extracting /wiki/Killing_of_Patrick_Lyoya
# Added 705 links
# extracting /wiki/1963_in_the_United_Kingdom
# Added 731 links
# extracting /wiki/Texas_Department_of_Public_Safety
# Added 159 links
# extracting /wiki/Theodore_Roosevelt_National_Park
# Added 525 links
# extracting /wiki/Military_history_of_Australia_during_World_War_II
# Added 1354 links
# extracting /wiki/Benjamin_I_of_Constantinople
# Added 310 links
# extracting /wiki/Pisa
# Added 621 links
# extracting /wiki/Birth_rate
# Added 241 links
# extracting /wiki/Dzongkha_Braille
# Added 149 links
# extracting /wiki/Joseph_Goebbels
# Added 2321 links
# extracting /wiki/Pak_Jong-chon
# Added 138 links
# extracting /wiki/Speech_Recognition_Grammar_Specification
# Added 140 links
# extracting /wiki/Precious_(wrestling)
# Added 54 links
# extracting /wiki/Sex_symbol
# Added 127 links
# extracting /wiki/Putinism
# Added 3338 links
# extracting /wiki/Je_suis_partout
# Added 1417 links
# extracting /wiki/Nikkolas_Smith
# Added 70 links
# extracting /wiki/United_States_congressional_delegations_from_Wisconsin
# Added 938 links
# extracting /wiki/Thomas_Cochrane,_10th_Earl_of_Dundonald
# Added 466 links
# extracting /wiki/Brisbane
# Added 2314 links
# extracting /wiki/October_21
# Added 1166 links
# extracting /wiki/Volodymyr_Zelenskyy
# Added 2103 links
# extracting /wiki/Carbon_Neutral_Cities_Alliance
# Added 26 links
# extracting /wiki/Bricker_Amendment
# Added 1088 links
# extracting /wiki/South_African_English
# Added 1090 links
# extracting /wiki/Chanhassen,_Minnesota
# Added 417 links
# extracting /wiki/Vinted
# Added 17 links
# extracting /wiki/Kim_%C5%ACngu
# Added 51 links
# extracting /wiki/Albertina
# Added 54 links
# extracting /wiki/Katerina_Sakellaropoulou
# Added 121 links
# extracting /wiki/Harvey_Klehr
# Added 526 links
# ...
# Added 154 links
# extracting /wiki/Energy_in_Sudan
# Added 93 links
# extracting /wiki/Sylvanus_Olympio
# Added 106 links
# extracting /wiki/Andrey_Aleksandrovich_Medvedev
# Added 724 links
# extracting /wiki/Military_operations_other_than_war_(US)
# Added 27 links
# extracting /wiki/List_of_islands_of_Australia
# Added 689 links
# extracting /wiki/Case_system
# Added 592 links
# extracting /wiki/Fall_of_the_Iron_Curtain
# Added 2864 links
# extracting /wiki/Fontella_Bass
# Added 157 links
# extracting /wiki/Ralph_Fiennes
# Added 1222 links
# extracting /wiki/Treaty_of_Villafranca
# Added 505 links
# extracting /wiki/Evropesma
# Added 359 links
# extracting /wiki/Housing_in_Portugal
# Added 69 links
# extracting /wiki/Bureau_of_Diplomatic_Security
# Added 287 links
# extracting /wiki/Vijay_Singh
# Added 1436 links
# extracting /wiki/William_Luers
# Added 104 links
# extracting /wiki/United_Nations_Fact_Finding_Mission_on_the_2014_Israel%E2%80%93Gaza_conflict
# Added 321 links
# extracting /wiki/Yang_di-Pertua_Negeri_of_Sabah
# Added 174 links
# extracting /wiki/King_Alfred
# Added 761 links
# extracting /wiki/A_ZBC_of_Ezra_Pound
# Added 70 links
# extracting /wiki/Moldovan_resistance_during_World_War_II
# Added 446 links
# extracting /wiki/George_Brent
# Added 327 links
# extracting /wiki/May_1938
# Added 392 links
# extracting /wiki/Pierre_Lanfrey
# Added 15 links
# extracting /wiki/AC_Cesena
# Added 216 links
# extracting /wiki/Antoni_Mart%C3%AD
# Added 132 links
# extracting /wiki/Quadrumvirs
# Added 1201 links
# extracting /wiki/August_9
# Added 1114 links
# extracting /wiki/1963_in_music
# Added 1539 links
# extracting /wiki/Sixth_National_Government_of_New_Zealand
# Added 1494 links
# extracting /wiki/Codebook
# Added 28 links
# extracting /wiki/Historiography_of_the_May_Revolution
# Added 750 links
# extracting /wiki/Rocky_Bleier
# Added 688 links
# extracting /wiki/Siege_of_Lille_(1792)
# Added 173 links
# extracting /wiki/Gary_Burghoff
# Added 165 links
# extracting /wiki/Marie_NDiaye
# Added 379 links
# extracting /wiki/Tulkarm_Brigade
# Added 220 links
# extracting /wiki/Peter_Boardman
# Added 85 links
# extracting /wiki/GoFundMe
# Added 218 links
# extracting /wiki/CBS_Morning_News
# Added 168 links
# extracting /wiki/Nick_Jr._(Turkish_TV_channel)
# Added 989 links
# extracting /wiki/Postmodern_art
# Added 1102 links
# extracting /wiki/Cipher
# Added 165 links
# extracting /wiki/Reynato_Puno
# Added 256 links
# extracting /wiki/Demi-brigade
# Added 50 links
# extracting /wiki/Al-Aqsa_Voice_Radio
# Added 187 links
# extracting /wiki/Jean_Baptiste_Colbert,_Marquis_of_Torcy
# Added 228 links
# extracting /wiki/Defiance_(book)
# Added 317 links
# extracting /wiki/Karol_Szymanowski
# Added 304 links
# extracting /wiki/2020_Democratic_Party_presidential_primaries
# Added 2343 links
# extracting /wiki/Circassians
# Added 1191 links
# extracting /wiki/Calcinosis
# Added 61 links
# extracting /wiki/Landscape_painting
# Added 595 links
# extracting /wiki/Public_Television_Company_of_Armenia
# Added 447 links
# extracting /wiki/Tashi_Wangdi
# Added 11 links
# extracting /wiki/N%27djili_Airport
# Added 197 links
# extracting /wiki/Italian_War_of_1542%E2%80%931546
# Added 381 links
# extracting /wiki/Mexican_Fascist_Party
# Added 384 links
# extracting /wiki/Kentucky_Wildcats
# Added 636 links
# extracting /wiki/History_of_medicine_in_France
# Added 53 links
# extracting /wiki/John_McGeoch
# Added 386 links
# extracting /wiki/Su-27
# Added 652 links
# extracting /wiki/Josip_Broz_Tito
# Added 2167 links
# extracting /wiki/Amadigi_di_Gaula
# Added 280 links
# extracting /wiki/Ernest_Dominique_Fran%C3%A7ois_Joseph_Duquesnoy
# Added 23 links
# extracting /wiki/Lothair_I
# Added 344 links
# extracting /wiki/LRT_televizija
# Added 207 links
# extracting /wiki/SADC_Mission_in_the_Democratic_Republic_of_Congo
# Added 24 links
# extracting /wiki/Pope_John_X
# Added 440 links
# extracting /wiki/Antoine-Fran%C3%A7ois_Momoro
# Added 50 links
# extracting /wiki/The_News_%26_Observer
# Added 193 links
# extracting /wiki/Marxism%E2%80%93Leninism
# Added 2879 links
# extracting /wiki/KTXA
# Added 528 links
# extracting /wiki/Stefania_Sandrelli
# Added 691 links
# extracting /wiki/La_Lucila
# Added 150 links
# extracting /wiki/South_West_Africa
# Added 488 links
# extracting /wiki/Crucifix
# Added 324 links
# extracting /wiki/Henryk_Dobrza%C5%84ski
# Added 158 links
# extracting /wiki/Red_Allen
# Added 90 links
# extracting /wiki/Friedrich_Hayek
# Added 2523 links
# extracting /wiki/Archduke_Felix_of_Austria
# Added 186 links
# extracting /wiki/Buenos_Aires_Sings
# Added 16 links
# extracting /wiki/Agriculture_in_Sudan
# Added 377 links
# extracting /wiki/Apollo_7
# Added 460 links
# extracting /wiki/Republic_of_Connacht
# Added 128 links
# extracting /wiki/Lisbon_(Assembly_of_the_Republic_constituency)
# Added 894 links
# extracting /wiki/XProc
# Added 129 links
# extracting /wiki/List_of_kings_of_Burgundy
# Added 287 links
# extracting /wiki/What_the_Hell_Just_Happened%3F
# Added 453 links
# extracting /wiki/National_Parliament_(East_Timor)
# Added 400 links
# extracting /wiki/March_19
# Added 1042 links
# extracting /wiki/Explorer_32
# Added 305 links
# extracting /wiki/Western_European_Union
# Added 338 links
# extracting /wiki/Reactions_to_the_death_of_Kim_Jong_Il
# Added 271 links
# extracting /wiki/56th_Annual_Grammy_Awards#Classical
# Added 1647 links
# extracting /wiki/1959_Mosul_uprising
# Added 1322 links
# extracting /wiki/Operation_Keelhaul
# Added 474 links
# extracting /wiki/Melilla
# Added 818 links
# extracting /wiki/Gross_domestic_product
# Added 585 links
# extracting /wiki/Hennepin_Avenue_Bridge
# Added 60 links
# extracting /wiki/August_2022
# Added 1519 links
# extracting /wiki/Asteromata
# Added 239 links
# extracting /wiki/Romanians
# Added 952 links
# extracting /wiki/Sammarinese_Fascist_Party
# Added 1370 links
# extracting /wiki/Gerald_Thomas_Walsh
# Added 378 links
# extracting /wiki/Claudius
# Added 1233 links
# extracting /wiki/Vilho_Helanen
# Added 173 links
# extracting /wiki/Canlers
# Added 818 links
# extracting /wiki/Jean_%C3%89tienne_Vachier_Championnet
# Added 58 links
# extracting /wiki/Battle_of_Wagram
# Added 765 links
# extracting /wiki/Espanca_script
# Added 519 links
# extracting /wiki/Vox_(website)
# Added 137 links
# extracting /wiki/Proto-Germanic_language
# Added 920 links
# extracting /wiki/Indian_subcontinent
# Added 557 links
# extracting /wiki/Battle_of_Tarawa
# Added 193 links
# extracting /wiki/Moscow_school
# Added 53 links
# extracting /wiki/Australian_tonalism
# Added 529 links
# extracting /wiki/Latin_America
# Added 1922 links
# extracting /wiki/Liguria
# Added 1046 links
# extracting /wiki/Khartoum
# Added 462 links
# extracting /wiki/Andrew_Sznajder
# Added 130 links
# extracting /wiki/2020_in_Armenia
# Added 148 links
# extracting /wiki/King_of_Italy#Kingdom_of_Italy_(781–962)
# Added 641 links
# extracting /wiki/British_West_Indian_labour_unrest_of_1934%E2%80%9339
# Added 61 links
# extracting /wiki/John_H._Thompson
# Added 28 links
# extracting /wiki/Basil_Bunting
# Added 464 links
# extracting /wiki/Alt-right_pipeline
# Added 421 links
# extracting /wiki/Hind%C3%BA_Club
# Added 65 links
# extracting /wiki/Yanji
# Added 222 links
# extracting /wiki/Girondins
# Added 692 links
# extracting /wiki/April_1939
# Added 397 links
# extracting /wiki/Spingarn_Medal
# Added 625 links
# extracting /wiki/Mechelen
# Added 383 links
# extracting /wiki/Indianapolis_500
# Added 928 links
# extracting /wiki/Macmillan_and_Company
# Added 265 links
# extracting /wiki/Tela_(rapper)
# Added 45 links
# extracting /wiki/History_of_Minnesota
# Added 756 links
# extracting /wiki/Jungfraujoch
# Added 118 links
# extracting /wiki/Georg_Olden_(graphic_designer)
# Added 44 links
# extracting /wiki/SWIFT_ban_against_Russian_banks
# Added 839 links
# extracting /wiki/Bezengi_Glacier
# Added 17 links
# extracting /wiki/Pope_Urban_IV
# Added 942 links
# extracting /wiki/Charles_Alfred_Pillsbury
# Added 85 links
# extracting /wiki/Culture_of_the_Southern_United_States
# Added 1016 links
# extracting /wiki/Julius_Streicher
# Added 401 links
# extracting /wiki/2018%E2%80%9319_Korean_peace_process
# Added 559 links
# extracting /wiki/Separate_but_equal
# Added 898 links
# extracting /wiki/Mihail_Sadoveanu
# Added 1176 links
# extracting /wiki/List_of_largest_empires
# Added 682 links
# extracting /wiki/Juan_Moreira_(1973_film)
# Added 91 links
# extracting /wiki/MTV_Brand_New_(Italian_TV_channel)
# Added 751 links
# extracting /wiki/Swiss_Plateau
# Added 385 links
# extracting /wiki/Thomas_K%C3%B6hler
# Added 262 links
# extracting /wiki/Second_Battle_of_Kitshanga
# Added 48 links
# extracting /wiki/Matthew_Best_(conductor)
# Added 82 links
# extracting /wiki/Democratic_Forces_for_the_Liberation_of_Rwanda
# Added 197 links
# extracting /wiki/April_2015
# Added 815 links
# extracting /wiki/Gangs_in_the_United_States
# Added 391 links
# extracting /wiki/Lindsey_Graham
# Added 1566 links
# extracting /wiki/Kingsway_East,_St._Louis
# Added 98 links
# extracting /wiki/She_Chinese
# Added 1007 links
# extracting /wiki/Drifter_(fishing_boat)
# Added 222 links
# extracting /wiki/Austrian_Nazism
# Added 1357 links
# extracting /wiki/Police_racism
# Added 691 links
# extracting /wiki/Diplomatic_history_of_World_War_II
# Added 1348 links
# extracting /wiki/Eastern_Hemisphere
# Added 360 links
# extracting /wiki/Gavrelle
# Added 816 links
# extracting /wiki/Next_North_Korean_parliamentary_election
# Added 152 links
# extracting /wiki/2007%E2%80%932008_Kenyan_crisis
# Added 453 links
# extracting /wiki/Ternas
# Added 816 links
# extracting /wiki/Adriatic_Sea
# Added 2000 links
# extracting /wiki/2009
# Added 797 links
# extracting /wiki/Apennine_Colossus
# Added 76 links
# extracting /wiki/Michael_Schwerner
# Added 559 links
# extracting /wiki/Gadsden_Confederate_Memorial
# Added 123 links
# extracting /wiki/Dust_storm_warning
# Added 147 links
# extracting /wiki/Gus_Grissom
# Added 632 links
# extracting /wiki/Real_America%27s_Voice
# Added 111 links
# extracting /wiki/Henry_IV_of_France
# Added 717 links
# extracting /wiki/Severe_acute_respiratory_syndrome_coronavirus_2
# Added 2807 links
# extracting /wiki/November_4
# Added 1078 links
# extracting /wiki/Dylan_Thomas
# Added 470 links
# extracting /wiki/TV1_(Estonian_TV_channel)
# Added 94 links
# extracting /wiki/Legislation.gov.uk
# Added 800 links
# extracting /wiki/Gaja_(song)
# Added 207 links
# extracting /wiki/Archives_Nationales_(France)
# Added 178 links
# extracting /wiki/List_of_earthquakes_in_Portugal
# Added 63 links
# extracting /wiki/United_Nations_Security_Council_Resolution_2728
# Added 495 links
# extracting /wiki/History_of_African_Americans_in_Jacksonville,_Florida
# Added 701 links
# extracting /wiki/International_uniformity_of_braille_alphabets
# Added 221 links
# extracting /wiki/Nation_Party_of_Iran
# Added 110 links
# extracting /wiki/Eurovision_Song_Contest_winners_discography
# Added 810 links
# extracting /wiki/Arequito_Revolt
# Added 119 links
# extracting /wiki/The_Dakotas
# Added 94 links
# extracting /wiki/Eric_Schmidt
# Added 1672 links
# extracting /wiki/BET_International
# Added 502 links
# extracting /wiki/Canadian_Oxford_Dictionary
# Added 70 links
# extracting /wiki/The_Boston_Globe
# Added 699 links
# extracting /wiki/Eurovision_Song_Contest_1962
# Added 620 links
# extracting /wiki/Thelaziasis
# Added 203 links
# extracting /wiki/Olympia_Press
# Added 98 links
# extracting /wiki/Battle_of_Nanking
# Added 303 links
# extracting /wiki/Assassination_of_Iranian_nuclear_scientists
# Added 270 links
# extracting /wiki/Proto-fascism
# Added 68 links
# extracting /wiki/The_Voice_of_Germany
# Added 693 links
# extracting /wiki/1881
# Added 782 links
# extracting /wiki/Central_Northern_Railway
# Added 132 links
# extracting /wiki/RAF_Fighter_Command
# Added 354 links
# extracting /wiki/Beugin
# Added 818 links
# extracting /wiki/Cambridge
# Added 995 links
# extracting /wiki/Zapotec_script
# Added 209 links
# extracting /wiki/Coleus
# Added 93 links
# extracting /wiki/Religion_in_Jordan
# Added 213 links
# extracting /wiki/Withdrawal_of_Joe_Biden_from_the_2024_United_States_presidential_election
# Added 806 links
# extracting /wiki/Isthmian_script
# Added 685 links
# extracting /wiki/Robert_Morley
# Added 433 links
# extracting /wiki/Manitoba
# Added 1119 links
# extracting /wiki/Marine_Park,_Brooklyn
# Added 211 links
# extracting /wiki/Maine
# Added 1568 links
# extracting /wiki/Journal_of_Aesthetics_and_Art_Criticism
# Added 24 links
# extracting /wiki/President_of_Russia
# Added 945 links
# extracting /wiki/Phrasal_verb
# Added 281 links
# extracting /wiki/Slade
# Added 635 links
# extracting /wiki/Rosen_Zhelyazkov
# Added 471 links
# extracting /wiki/Google_Pinyin
# Added 986 links
# extracting /wiki/Min_Ping_Yu_No._5202
# Added 193 links
# extracting /wiki/Legislature_of_the_Marshall_Islands
# Added 290 links
# extracting /wiki/Balthazar_Alexis_Henri_Schauenburg
# Added 60 links
# extracting /wiki/Progressive_enhancement
# Added 89 links
# extracting /wiki/Per_Brahe_the_Younger
# Added 93 links
# extracting /wiki/Patrick_Gabarrou
# Added 20 links
# extracting /wiki/Ferrocarril_de_San_Crist%C3%B3bal_a_Tucum%C3%A1n
# Added 81 links
# extracting /wiki/Storm-Z
# Added 78 links
# extracting /wiki/Serge_Savard
# Added 144 links
# extracting /wiki/Quilmes
# Added 193 links
# extracting /wiki/Open-mid_front_unrounded_vowel
# Added 689 links
# extracting /wiki/Killdeer
# Added 206 links
# extracting /wiki/Rollback
# Added 821 links
# extracting /wiki/Sirba_massacre
# Added 20 links
# extracting /wiki/Philippe_of_Belgium
# Added 440 links
# extracting /wiki/Official_development_assistance
# Added 33 links
# extracting /wiki/Detribalization
# Added 517 links
# extracting /wiki/TheGuardian.com
# Added 1359 links
# extracting /wiki/Open_standard
# Added 346 links
# extracting /wiki/W%C4%81puro_r%C5%8Dmaji
# Added 235 links
# extracting /wiki/Julia_Varela
# Added 19 links
# extracting /wiki/2007_Likud_leadership_election
# Added 155 links
# extracting /wiki/Bernardino_Rivadavia_Natural_Sciences_Museum
# Added 191 links
# extracting /wiki/Caf%C3%A9_Central
# Added 44 links
# extracting /wiki/Ow%C3%A1mniyomni
# Added 294 links
# extracting /wiki/Israeli_demolition_of_Palestinian_property
# Added 796 links
# extracting /wiki/Fascist_syndicalism
# Added 406 links
# extracting /wiki/Sheikh_Ahmed_Yassin
# Added 1214 links
# extracting /wiki/Yevgeny_Tarle
# Added 113 links
# extracting /wiki/Corinne_Herm%C3%A8s
# Added 390 links
# extracting /wiki/Ferguson_Action
# Added 52 links
# extracting /wiki/Shortgrass_prairie
# Added 128 links
# extracting /wiki/Military_history_of_Turkey#World_War_II
# Added 576 links
# extracting /wiki/Aiko_(Czech_singer)
# Added 195 links
# extracting /wiki/Un_premier_amour
# Added 516 links
# extracting /wiki/Neeru_Khosla
# Added 14 links
# extracting /wiki/White_supremacist
# Added 2006 links
# extracting /wiki/7th_Hussar_Regiment_(France)
# Added 21 links
# extracting /wiki/Ren%C3%A9_Dif
# Added 90 links
# extracting /wiki/Wilhelm_II
# Added 1000 links
# extracting /wiki/List_of_Presidential_Medal_of_Freedom_recipients
# Added 1576 links
# extracting /wiki/President_of_Guatemala
# Added 502 links
# extracting /wiki/John_Key
# Added 909 links
# extracting /wiki/2020_election_in_the_United_States
# Added 1565 links
# extracting /wiki/List_of_political_parties_in_Portugal
# Added 833 links
# extracting /wiki/French_navy
# Added 771 links
# extracting /wiki/Pont-Aven_School
# Added 583 links
# extracting /wiki/Convention_of_Mantua
# Added 24 links
# extracting /wiki/Douriez
# Added 816 links
# extracting /wiki/United_States_Institute_of_Peace
# Added 148 links
# extracting /wiki/Battle_of_Dak_To
# Added 540 links
# extracting /wiki/Statue_of_Christopher_Columbus_(Newark,_New_Jersey)
# Added 128 links
# extracting /wiki/2012_Democratic_National_Convention
# Added 1459 links
# extracting /wiki/Target_Center
# Added 544 links
# extracting /wiki/John_DeFrancis
# Added 107 links
# extracting /wiki/Kyosti_Kallio
# Added 281 links
# extracting /wiki/Homer_Pound_House
# Added 89 links
# extracting /wiki/ORT_Argentina
# Added 25 links
# extracting /wiki/New_Montgomery_Street
# Added 175 links
# extracting /wiki/Dynamic_HTML
# Added 260 links
# extracting /wiki/KMSP-TV
# Added 1286 links
# extracting /wiki/Vimy
# Added 832 links
# extracting /wiki/Not_a_River
# Added 14 links
# extracting /wiki/English_phonology
# Added 645 links
# extracting /wiki/Atlanta%E2%80%93Athens-Clarke_County%E2%80%93Sandy_Springs,_GA_Combined_Statistical_Area
# Added 1499 links
# extracting /wiki/Australian_Defence_League
# Added 265 links
# extracting /wiki/Tao_Xingzhi
# Added 55 links
# extracting /wiki/Georges_Lefebvre
# Added 24 links
# extracting /wiki/Transjordan_memorandum
# Added 58 links
# extracting /wiki/Ministry_of_Defence_(Zimbabwe)
# Added 119 links
# extracting /wiki/Selva_de_Pedra_(1972_TV_series)
# Added 349 links
# extracting /wiki/Edict_of_Milan
# Added 77 links

# %%
len(all_texts)
# Out:
# 290879

# %%
len(set(all_texts))
# Out:
# 261820

# %%
from collections import Counter
for paragraph, count in Counter(all_texts).most_common(10):
    print(f"{count}x: {paragraph[:80]}...")
# Out:
# 85x: ThisPas-de-Calaisgeographical article is astub. You can help Wikipedia byexpandi...
# 63x: ThisArras arrondissement, Pas-de-Calaisgeographical article is astub. You can he...
# 50x: Note: Flags indicate national team as defined underFIFA eligibility rules; some ...
# 24x: ThisArrondissement of Lillegeographical article is astub. You can help Wikipedia...
# 22x: ThisArrondissement of Avesnes-sur-Helpegeographical article is astub. You can he...
# 18x: This article about a place inBuenos Aires Province,Argentinais astub. You can he...
# 17x: Aircraft of comparable role, configuration, and era...
# 16x: ThisArrondissement of Cambraigeographical article is astub. You can help Wikiped...
# 16x: Annual Goals Progress onSafety & IntegritySee also blogs:Global Advocacy blog·Gl...
# 15x: ThisArrondissement of Dunkirkgeographical article is astub. You can help Wikiped...

# %%
model = defaultdict(lambda: defaultdict(lambda: 0))

for l in all_texts['text']:
    tokens = word_tokenize(l)
    for gram in ngrams(tokens, n):
        context = gram[:-1]
        next_word = gram[-1]
        model[context][next_word] += 1

for context in model:
    total = sum(model[context].values())
    for next_word in model[context]:
        model[context][next_word] /= total

# %%
def generate_text(seed, max_words=100):
    if len(seed) != n - 1:
        raise ValueError(f"Seed must be of length {n-1} for an n-gram model with n={n}.")

    output = list(seed)
    current_context = tuple(seed)

    for _ in range(max_words):
        next_words = model.get(current_context, None)
        if not next_words:
            break

        words, probs = zip(*next_words.items())
        next_word = random.choices(words, probs)[0]
        output.append(next_word)

        current_context = (*current_context[1:], next_word)

    return ' '.join(output)

# %%
generate_text(["armies", "in", "the"], 100)
# Out:
# 'armies in the'

# %%
generate_text(["the", "thing", "is"], 100)
# Out:
# "the thing named by the conservative-ledConstitutional Council . [ 137 ] Charles 's daughter , `` I ’ m Dan Patrick Show , which required allegiance to theFederal Reserve Board chairmanAlan Greenspan , a steady partner . [ 140 ] Morton La Kretz Bridge has remained controversial to this date , the Design and Development Promotion Law . [ 80 ] The town grew into a castle . [ 2 ] [ 24 ] Hyundai planned to be covered with putrefying bed sores , but what constitutes courtesy , and other parts of India . [ 218 ] most notably playing Doctor"

# %%
generate_text(["it", "can", "be", ""], 100)
# Out:
# 'it can be said'

# %%
import csv

def save_model_to_csv(model, filename=f'{n}gram_model.csv'):
    with open(filename, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['context', 'next_word', 'probability'])

        for context, next_words in model.items():
            context_str = ' '.join(context)
            for next_word, prob in next_words.items():
                writer.writerow([context_str, next_word, prob])
                
save_model_to_csv(model)

# %%
def load_model_from_csv(filename=f'{n}gram_model.csv'):
    model = defaultdict(lambda: defaultdict(float))
    with open(filename, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            context = tuple(row['context'].split())
            next_word = row['next_word']
            prob = float(row['probability'])
            model[context][next_word] = prob
    return model
model = load_model_from_csv()
